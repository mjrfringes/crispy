# %% [markdown]
# # Starting an IFS simulation from scratch

# %% [markdown]
# Let's suppose that you want to model the ideal IFS and don't have any idea (or don't really care) about what the PSFLets look like and where they are located. In that case, you don't need any datafile and can get started ASAP!

# %% [markdown]
# Let's load things first.

# %%
import numpy as np
import glob
# %pylab inline --no-import-all
plt.rc('font', family='serif', serif='Times',size=20)
plt.rc('text', usetex=True)
plt.rc('xtick', labelsize=20)
plt.rc('xtick.major', size=10)
plt.rc('ytick.major', size=10)
plt.rc('ytick', labelsize=20)
plt.rc('axes', labelsize=20)
plt.rc('figure',titlesize=20)
plt.rc('image',origin='lower',interpolation='nearest')

import sys
import os
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Initializes the logger used throughout the software

# %%
from crispy.tools.initLogger import getLogger
log = getLogger('crispy')

# %% [markdown]
# ### Operate in your working directory (where your parameter file lives)

# %%
os.chdir('/Users/mrizzo/IFS/crispy/crispy/WFIRST_tight/')
# os.chdir('/Users/mrizzo/IFS/crispy/crispy/WFIRST_SC/')

# %% [markdown]
# ### Load parameters

# %%
from params import Params
par = Params()
par.hdr
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# COMMENT
# COMMENT ************************************************************
# COMMENT ********************** General parameters ******************
# COMMENT ************************************************************
# COMMENT
# NLENS   =                  108 / # lenslets across array
# PITCH   =             0.000174 / Lenslet pitch (meters)
# INTERLAC=                  2.0 / Interlacing
# PHILENS =    26.56505117707799 / Rotation angle of the lenslets (deg)
# PIXSIZE =              1.3E-05 / Pixel size (meters)
# LENSAMP =                  0.5 / Lenslet sampling (lam/D)
# LSAMPWAV=                770.0 / Lenslet sampling wavelength (nm)
# FWHM    =                  1.0 / FHWM of PSFLet at detector (pixels)
# FWHMLAM =                770.0 / Wavelength at which FWHM is defined (nm)
# NPIX    =                 1024 / Number of detector pixels
# BW      =                 0.18 / Bandwidth
# PIXPRLAM=                  2.0 / Pixels per resolution element
# RESLSTSQ=                  2.0 / Nspec per Nyq. sample for lstsq extraction
# R       =                   50 / Spectral resolution

# %% [markdown]
# First off, you are going to trick crispy into building a fake wavelength calibration. This is usually important because in the real world, the wavelength calibration is the step that ensures that you can get good data out of your IFS images. For this exercise, you are going to use an a priori wavelength calibration (it's built into crispy) to generate monochromatic flatfields. From these flatfields, you are going to build up your wavelength calibration - just like in real life!

# %% [markdown]
# ## Generate monochromatic flats

# %% [markdown]
# So, what's our wavelength range? We are going to use the fiducial case of 600nm - 720nm, which is the first band of the WFIRST IFS. We are going to construct a few monochromatic flats across that range. The function we need is in the IFS module (that one has a lot of important functions).

# %%
from crispy.IFS import createWavecalFiles
help(createWavecalFiles)
# Out:
# Help on function createWavecalFiles in module crispy.IFS:
#
# createWavecalFiles(par, lamlist, dlam=1.0, flux=None, background=0.0)
#     Creates a set of monochromatic IFS images to be used in wavelength calibration step
#
#     Parameters
#     ----------
#     par:   Parameter instance
#             Contains all IFS parameters
#     lamlist: list or array of floats
#             List of discrete wavelengths in nm at which to create a monochromatic flat
#     dlam:  float
#             Width in nm of the small band for each of the monochromatic wavelengths.
#             Default is 1 nm. This has no effect unless we are trying to add any noise.
#     flux: float
#             Number of counts per lenslet. If a noiseless
#             image is preferred, leave this to None
#     background: float
#             Adds Poisson-distributed background to the image. Leave to None to ignore.
#
#     Notes
#     -----
#     This function populates the fields par.lamlist and par.filelist which are subsequently
#     used by the buildcalibrations function. If this createWavecalFiles is not called, the
#     two fields need to be populated manually with the set of files and wavelengths that
#     you want to use for the calibration.

# %% [markdown]
# So here we go:

# %%
lamc=770.
lamlist = np.arange(lamc*(1.-par.BW/2.),lamc*(1.+par.BW/2.)+5.,5.)
# lamlist = lamc*np.linspace(1.-BW/2.,1.+BW/2.,fileshape[0])

# let's create our new wavelength calibration directory to not mess up anything
# comment this out if this was already done and you are fine overriding the files in your folder
# try:
#     os.makedirs(par.prefix+'/testWavecal660')
# except OSError:
#     log.error('Wavecal folder already exists!')
#     raise

log.info('Wavecal folder is: %s' % par.wavecalDir)
log.info(lamlist)
# Out:
# crispy - INFO - Wavecal folder is: ..//ReferenceFiles/wavecalR50_770_tight/
# crispy - INFO - [700.7 705.7 710.7 715.7 720.7 725.7 730.7 735.7 740.7 745.7 750.7 755.7
#  760.7 765.7 770.7 775.7 780.7 785.7 790.7 795.7 800.7 805.7 810.7 815.7
#  820.7 825.7 830.7 835.7 840.7]

# %%
flist = createWavecalFiles(par,lamlist,flux=200,background=10)
# Out:
# crispy - INFO - The number of input pixels per lenslet is 4.995459
# crispy - INFO - Using PSFlet gaussian approximation
# crispy - WARNING - Assuming slices are evenly spread in wavelengths
# crispy - INFO - Creating Gaussian PSFLet templates
# crispy - INFO - Writing data to ..//SimResults/detectorFramepoly.fits
# crispy - INFO - Done.
# crispy - INFO - Performance: 5 seconds total
# crispy - INFO - Writing data to ..//ReferenceFiles/wavecalR50_770_tight/det_700.fits
# crispy - INFO - The number of input pixels per lenslet is 4.995459
# crispy - INFO - Using PSFlet gaussian approximation
# crispy - WARNING - Assuming slices are evenly spread in wavelengths
# crispy - INFO - Creating Gaussian PSFLet templates
# crispy - INFO - Writing data to ..//SimResults/detectorFramepoly.fits
# crispy - INFO - Done.
# crispy - INFO - Performance: 5 seconds total
# crispy - INFO - Writing data to ..//ReferenceFiles/wavecalR50_770_tight/det_705.fits
# crispy - INFO - The number of input pixels per lenslet is 4.995459
# crispy - INFO - Using PSFlet gaussian approximation
# crispy - WARNING - Assuming slices are evenly spread in wavelengths
# crispy - INFO - Creating Gaussian PSFLet templates
# crispy - INFO - Writing data to ..//SimResults/detectorFramepoly.fits
# crispy - INFO - Done.
# crispy - INFO - Performance: 5 seconds total
# crispy - INFO - Writing data to ..//ReferenceFiles/wavecalR50_770_tight/det_710.fits
# crispy - INFO - The number of input pixels per lenslet is 4.995459
# crispy - INFO - Using PSFlet gaussian approximation
# crispy - WARNING - Assuming slices are evenly spread in wavelengths
# crispy - INFO - Creating Gaussian PSFLet templates
# crispy - INFO - Writing data to ..//SimResults/detectorFramepoly.fits
# crispy - INFO - Done.
# crispy - INFO - Performance: 5 seconds total
# crispy - INFO - Writing data to ..//ReferenceFiles/wavecalR50_770_tight/det_715.fits
# crispy - INFO - The number of input pixels per lenslet is 4.995459
# crispy - INFO - Using PSFlet gaussian approximation
# crispy - WARNING - Assuming slices are evenly spread in wavelengths
# crispy - INFO - Creating Gaussian PSFLet templates
# crispy - INFO - Writing data to ..//SimResults/detectorFramepoly.fits
# crispy - INFO - Done.
# crispy - INFO - Performance: 4 seconds total
# crispy - INFO - Writing data to ..//ReferenceFiles/wavecalR50_770_tight/det_720.fits
# crispy - INFO - The number of input pixels per lenslet is 4.995459
# crispy - INFO - Using PSFlet gaussian approximation
# crispy - WARNING - Assuming slices are evenly spread in wavelengths
# crispy - INFO - Creating Gaussian PSFLet templates
# crispy - INFO - Writing data to ..//SimResults/detectorFramepoly.fits
# crispy - INFO - Done.
# crispy - INFO - Performance: 4 seconds total
# crispy - INFO - Writing data to ..//ReferenceFiles/wavecalR50_770_tight/det_725.fits
# crispy - INFO - The number of input pixels per lenslet is 4.995459
# crispy - INFO - Using PSFlet gaussian approximation
# crispy - WARNING - Assuming slices are evenly spread in wavelengths
# crispy - INFO - Creating Gaussian PSFLet templates
# crispy - INFO - Writing data to ..//SimResults/detectorFramepoly.fits
# crispy - INFO - Done.
# crispy - INFO - Performance: 4 seconds total
# crispy - INFO - Writing data to ..//ReferenceFiles/wavecalR50_770_tight/det_730.fits
# crispy - INFO - The number of input pixels per lenslet is 4.995459
# crispy - INFO - Using PSFlet gaussian approximation
# crispy - WARNING - Assuming slices are evenly spread in wavelengths
# crispy - INFO - Creating Gaussian PSFLet templates
# crispy - INFO - Writing data to ..//SimResults/detectorFramepoly.fits
# crispy - INFO - Done.
# crispy - INFO - Performance: 4 seconds total
# crispy - INFO - Writing data to ..//ReferenceFiles/wavecalR50_770_tight/det_735.fits
# crispy - INFO - The number of input pixels per lenslet is 4.995459
# crispy - INFO - Using PSFlet gaussian approximation
# crispy - WARNING - Assuming slices are evenly spread in wavelengths
# crispy - INFO - Creating Gaussian PSFLet templates
# crispy - INFO - Writing data to ..//SimResults/detectorFramepoly.fits
# crispy - INFO - Done.
# crispy - INFO - Performance: 4 seconds total
# crispy - INFO - Writing data to ..//ReferenceFiles/wavecalR50_770_tight/det_740.fits
# crispy - INFO - The number of input pixels per lenslet is 4.995459
# crispy - INFO - Using PSFlet gaussian approximation
# crispy - WARNING - Assuming slices are evenly spread in wavelengths
# crispy - INFO - Creating Gaussian PSFLet templates
# crispy - INFO - Writing data to ..//SimResults/detectorFramepoly.fits
# crispy - INFO - Done.
# crispy - INFO - Performance: 4 seconds total
# crispy - INFO - Writing data to ..//ReferenceFiles/wavecalR50_770_tight/det_745.fits
# crispy - INFO - The number of input pixels per lenslet is 4.995459
# crispy - INFO - Using PSFlet gaussian approximation
# crispy - WARNING - Assuming slices are evenly spread in wavelengths
# crispy - INFO - Creating Gaussian PSFLet templates
# crispy - INFO - Writing data to ..//SimResults/detectorFramepoly.fits
# crispy - INFO - Done.
# crispy - INFO - Performance: 5 seconds total
# crispy - INFO - Writing data to ..//ReferenceFiles/wavecalR50_770_tight/det_750.fits
# crispy - INFO - The number of input pixels per lenslet is 4.995459
# crispy - INFO - Using PSFlet gaussian approximation
# crispy - WARNING - Assuming slices are evenly spread in wavelengths
# crispy - INFO - Creating Gaussian PSFLet templates
# crispy - INFO - Writing data to ..//SimResults/detectorFramepoly.fits
# crispy - INFO - Done.
# crispy - INFO - Performance: 5 seconds total
# crispy - INFO - Writing data to ..//ReferenceFiles/wavecalR50_770_tight/det_755.fits
# crispy - INFO - The number of input pixels per lenslet is 4.995459
# crispy - INFO - Using PSFlet gaussian approximation
# crispy - WARNING - Assuming slices are evenly spread in wavelengths
# crispy - INFO - Creating Gaussian PSFLet templates
# crispy - INFO - Writing data to ..//SimResults/detectorFramepoly.fits
# crispy - INFO - Done.
# crispy - INFO - Performance: 4 seconds total
# crispy - INFO - Writing data to ..//ReferenceFiles/wavecalR50_770_tight/det_760.fits
# crispy - INFO - The number of input pixels per lenslet is 4.995459
# crispy - INFO - Using PSFlet gaussian approximation
# crispy - WARNING - Assuming slices are evenly spread in wavelengths
# crispy - INFO - Creating Gaussian PSFLet templates
# crispy - INFO - Writing data to ..//SimResults/detectorFramepoly.fits
# crispy - INFO - Done.
# crispy - INFO - Performance: 4 seconds total
# crispy - INFO - Writing data to ..//ReferenceFiles/wavecalR50_770_tight/det_765.fits
# crispy - INFO - The number of input pixels per lenslet is 4.995459
# crispy - INFO - Using PSFlet gaussian approximation
# crispy - WARNING - Assuming slices are evenly spread in wavelengths
# crispy - INFO - Creating Gaussian PSFLet templates
# crispy - INFO - Writing data to ..//SimResults/detectorFramepoly.fits
# crispy - INFO - Done.
# crispy - INFO - Performance: 4 seconds total
# crispy - INFO - Writing data to ..//ReferenceFiles/wavecalR50_770_tight/det_770.fits
# crispy - INFO - The number of input pixels per lenslet is 4.995459
# crispy - INFO - Using PSFlet gaussian approximation
# crispy - WARNING - Assuming slices are evenly spread in wavelengths
# crispy - INFO - Creating Gaussian PSFLet templates
# crispy - INFO - Writing data to ..//SimResults/detectorFramepoly.fits
# crispy - INFO - Done.
# crispy - INFO - Performance: 5 seconds total
# crispy - INFO - Writing data to ..//ReferenceFiles/wavecalR50_770_tight/det_775.fits
# crispy - INFO - The number of input pixels per lenslet is 4.995459
# crispy - INFO - Using PSFlet gaussian approximation
# crispy - WARNING - Assuming slices are evenly spread in wavelengths
# crispy - INFO - Creating Gaussian PSFLet templates
# crispy - INFO - Writing data to ..//SimResults/detectorFramepoly.fits
# crispy - INFO - Done.
# crispy - INFO - Performance: 4 seconds total
# crispy - INFO - Writing data to ..//ReferenceFiles/wavecalR50_770_tight/det_780.fits
# crispy - INFO - The number of input pixels per lenslet is 4.995459
# crispy - INFO - Using PSFlet gaussian approximation
# crispy - WARNING - Assuming slices are evenly spread in wavelengths
# crispy - INFO - Creating Gaussian PSFLet templates
# crispy - INFO - Writing data to ..//SimResults/detectorFramepoly.fits
# crispy - INFO - Done.
# crispy - INFO - Performance: 4 seconds total
# crispy - INFO - Writing data to ..//ReferenceFiles/wavecalR50_770_tight/det_785.fits
# crispy - INFO - The number of input pixels per lenslet is 4.995459
# crispy - INFO - Using PSFlet gaussian approximation
# crispy - WARNING - Assuming slices are evenly spread in wavelengths
# crispy - INFO - Creating Gaussian PSFLet templates
# crispy - INFO - Writing data to ..//SimResults/detectorFramepoly.fits
# crispy - INFO - Done.
# crispy - INFO - Performance: 4 seconds total
# crispy - INFO - Writing data to ..//ReferenceFiles/wavecalR50_770_tight/det_790.fits
# crispy - INFO - The number of input pixels per lenslet is 4.995459
# crispy - INFO - Using PSFlet gaussian approximation
# crispy - WARNING - Assuming slices are evenly spread in wavelengths
# crispy - INFO - Creating Gaussian PSFLet templates
# crispy - INFO - Writing data to ..//SimResults/detectorFramepoly.fits
# crispy - INFO - Done.
# crispy - INFO - Performance: 4 seconds total
# crispy - INFO - Writing data to ..//ReferenceFiles/wavecalR50_770_tight/det_795.fits
# crispy - INFO - The number of input pixels per lenslet is 4.995459
# crispy - INFO - Using PSFlet gaussian approximation
# crispy - WARNING - Assuming slices are evenly spread in wavelengths
# crispy - INFO - Creating Gaussian PSFLet templates
# crispy - INFO - Writing data to ..//SimResults/detectorFramepoly.fits
# crispy - INFO - Done.
# crispy - INFO - Performance: 4 seconds total
# crispy - INFO - Writing data to ..//ReferenceFiles/wavecalR50_770_tight/det_800.fits
# crispy - INFO - The number of input pixels per lenslet is 4.995459
# crispy - INFO - Using PSFlet gaussian approximation
# crispy - WARNING - Assuming slices are evenly spread in wavelengths
# crispy - INFO - Creating Gaussian PSFLet templates
# crispy - INFO - Writing data to ..//SimResults/detectorFramepoly.fits
# crispy - INFO - Done.
# crispy - INFO - Performance: 4 seconds total
# crispy - INFO - Writing data to ..//ReferenceFiles/wavecalR50_770_tight/det_805.fits
# crispy - INFO - The number of input pixels per lenslet is 4.995459
# crispy - INFO - Using PSFlet gaussian approximation
# crispy - WARNING - Assuming slices are evenly spread in wavelengths
# crispy - INFO - Creating Gaussian PSFLet templates
# crispy - INFO - Writing data to ..//SimResults/detectorFramepoly.fits
# crispy - INFO - Done.
# crispy - INFO - Performance: 5 seconds total
# crispy - INFO - Writing data to ..//ReferenceFiles/wavecalR50_770_tight/det_810.fits
# crispy - INFO - The number of input pixels per lenslet is 4.995459
# crispy - INFO - Using PSFlet gaussian approximation
# crispy - WARNING - Assuming slices are evenly spread in wavelengths
# crispy - INFO - Creating Gaussian PSFLet templates
# crispy - INFO - Writing data to ..//SimResults/detectorFramepoly.fits
# crispy - INFO - Done.
# crispy - INFO - Performance: 5 seconds total
# crispy - INFO - Writing data to ..//ReferenceFiles/wavecalR50_770_tight/det_815.fits
# crispy - INFO - The number of input pixels per lenslet is 4.995459
# crispy - INFO - Using PSFlet gaussian approximation
# crispy - WARNING - Assuming slices are evenly spread in wavelengths
# crispy - INFO - Creating Gaussian PSFLet templates
# crispy - INFO - Writing data to ..//SimResults/detectorFramepoly.fits
# crispy - INFO - Done.
# crispy - INFO - Performance: 4 seconds total
# crispy - INFO - Writing data to ..//ReferenceFiles/wavecalR50_770_tight/det_820.fits
# crispy - INFO - The number of input pixels per lenslet is 4.995459
# crispy - INFO - Using PSFlet gaussian approximation
# crispy - WARNING - Assuming slices are evenly spread in wavelengths
# crispy - INFO - Creating Gaussian PSFLet templates
# crispy - INFO - Writing data to ..//SimResults/detectorFramepoly.fits
# crispy - INFO - Done.
# crispy - INFO - Performance: 4 seconds total
# crispy - INFO - Writing data to ..//ReferenceFiles/wavecalR50_770_tight/det_825.fits
# crispy - INFO - The number of input pixels per lenslet is 4.995459
# crispy - INFO - Using PSFlet gaussian approximation
# crispy - WARNING - Assuming slices are evenly spread in wavelengths
# crispy - INFO - Creating Gaussian PSFLet templates
# crispy - INFO - Writing data to ..//SimResults/detectorFramepoly.fits
# crispy - INFO - Done.
# crispy - INFO - Performance: 4 seconds total
# crispy - INFO - Writing data to ..//ReferenceFiles/wavecalR50_770_tight/det_830.fits
# crispy - INFO - The number of input pixels per lenslet is 4.995459
# crispy - INFO - Using PSFlet gaussian approximation
# crispy - WARNING - Assuming slices are evenly spread in wavelengths
# crispy - INFO - Creating Gaussian PSFLet templates
# crispy - INFO - Writing data to ..//SimResults/detectorFramepoly.fits
# crispy - INFO - Done.
# crispy - INFO - Performance: 4 seconds total
# crispy - INFO - Writing data to ..//ReferenceFiles/wavecalR50_770_tight/det_835.fits
# crispy - INFO - The number of input pixels per lenslet is 4.995459
# crispy - INFO - Using PSFlet gaussian approximation
# crispy - WARNING - Assuming slices are evenly spread in wavelengths
# crispy - INFO - Creating Gaussian PSFLet templates
# crispy - INFO - Writing data to ..//SimResults/detectorFramepoly.fits
# crispy - INFO - Done.
# crispy - INFO - Performance: 4 seconds total
# crispy - INFO - Writing data to ..//ReferenceFiles/wavecalR50_770_tight/det_840.fits

# %% [markdown]
# Let's take a look at what we did.

# %% [markdown]
# Now let's show some images. We use the Image module of crispy for convenience.

# %%
from crispy.tools.image import Image
plt.figure(figsize=(10,10))
plt.imshow(Image(flist[0]).data)
plt.colorbar(fraction=0.046, pad=0.04)
plt.show()
# Out:
# crispy - INFO - Read data from HDU 1 of ..//ReferenceFiles/wavecalR50_770_tight/det_700.fits

# %% [markdown]
# And a little zoom in:

# %%
plt.figure(figsize=(10,10))
plt.imshow(Image(flist[0]).data[450:550,450:550])
plt.colorbar(fraction=0.046, pad=0.04)
plt.show()
# Out:
# crispy - INFO - Read data from HDU 1 of ..//ReferenceFiles/wavecalR50_770_tight/det_700.fits

# %% [markdown]
# The PSFLets are slowly changing because the geometry that we chose results in almost integer spacing in both X and Y between neighboring lenslets. If you want more diversity (usually it is preferable to have diversity), then change the lenslet size of detector pitch by a little bit.

# %% [markdown]
# ## Run a complete wavelength calibration

# %% [markdown]
# Now that we have monochromatic flats, it is time to run a wavelength calibration, just like one would do in any IFS. The function we need is in crispy.tools.wavecal. This is a much more complicated function.

# %%
from crispy.tools.wavecal import buildcalibrations
help(buildcalibrations)
# Out:
# Help on function buildcalibrations in module crispy.tools.wavecal:
#
# buildcalibrations(par, filelist=None, lamlist=None, order=3, inspect=False, genwavelengthsol=False, makehiresPSFlets=False, makePolychrome=False, makehiresPolychrome=False, makePSFWidths=False, savehiresimages=True, borderpix=4, upsample=5, nsubarr=3, npix=13, parallel=True, inspect_first=True, apodize=False, lamsol=None, threshold=0.0, finecal=False, pxthreshold=2, findthreshold=5.0, trimfrac=0.0, apdiam=3, halfsize=5, snrthreshold=10, initcoef=None, readImgs=True)
#     Master wavelength calibration function
#
#     Parameters
#     ----------
#     par :   Parameter instance
#             Contains all IFS parameters
#     filelist: list of strings (optional)
#             List of the fits files that contain the monochromatic calibration files. If None (default),
#             use the files in par.filelist
#     lamlist: list of floats (optional)
#             Wavelengths in nm at which the files are taken. If None (default),
#             use the files in par.lamlist
#     order: int
#             Order of the polynomial used to fit the PSFLet positions across the detector
#     genwavelengthsol: Boolean
#             If True, generate the wavelength calibration. Creates a text file with all
#             polynomial coefficients that best fit the PSFLet positions at each wavelength.
#             If False, then load an already-generated file.
#     inspect: Boolean
#             Whether or not to create PNG files that overlay PSFLet fitted position on the
#             monochromatic pictures, to visually inspect the fitting results
#     inspect_first: Boolean
#             Whether or not to create a PNG file that overlays PSFLet fitted position on the
#             monochromatic picture of the first file, to visually inspect the fitting results
#     makehiresPSFlets: Boolean
#             Whether or not to do a high-resolution fitting of the PSFs, using the sampling
#             diversity. This requires high-SNR monochromatic images.
#     makePolychrome: Boolean
#             Whether or not to build the polychrome cube used in the least squares extraction
#     makePSFWidths: Boolean
#             Whether or not to fit the PSFLet widths using the high-res PSFLets
#     makehiresPolychrome: Boolean
#             Whether or not to build a polychrome cube at a high spatial resolution for future
#             subpixel interpolations
#     savehiresimages: Boolean
#             Whether to save fits files with the high-res PSFLets
#     borderpix:  int
#             Number of pixels that are not taken into account towards the edges of the detector
#     upsample: int
#             Upsampling factor for each high-resolution PSFLet
#     nsubarr: int
#             Detector will be divided into nsubarr x nsubarr regions. A high-resolution PSFLet
#             will be determined in each region from the average of all PSFLets within that
#             region
#     parallel: Boolean
#             Whether or not to parallelize the computation for the high-resolution PSFLet and
#             polychrome computation. The wavelength calibration step cannot be parallelized since
#             each wavelength uses the previous wavelength solution as a guess input.
#     apodize: Boolean
#             Whether to fit the spots only using lenslets within a circle, ignoring the corners of
#             the detector
#     lamsol: 2D array
#             Optional argument that, if not None and if genwavelengthsol==False, will take the argument
#             and use it as the current wavelength calibration to build the polychrome.
#     threshold: float
#             Threshold under which to zero out the polychrome. This is only useful for reducing
#             the file size of the polychrome, and has only very little impact on the extraction.
#             To be safe, for science extractions threshold should be kept at its default value of 0.0
#     finecal: boolean
#             Whether or not to perform fine calibration of all psflets individually through a
#             centroiding routine. Default: False
#     pxthreshold: float
#             Threshold under which the enhanced centroiding function will accept centroid corrections.
#             If a new centroid is more than pxthreshold away from a solution from the normal polynomial
#             calibration, it is rejected.
#     findthreshold: float
#             Number of standard deviations above which we look for point sources
#     trimfrac: float
#             Fraction of the psflets to discard during wavelength calibration (default 0.0)
#     apdiam: float
#             Aperture size in pixels used for snr calculation of the wavecal
#     halfsize: float
#             Half-size in pixels of the search region around each PSFlet for fine wavelength calibration
#     snrthreshold: float
#             Threshold below which we do not accept the fine wavelength calibration result, and stick
#             to the original polynomial fit
#     initcoef: numpy array
#             Coefficient array corresponding to an initial guess of the polynomial map. Leave to None
#             in order to start from scratch.
#
#
#     Notes
#     -----
#     This function generates all the files required to process IFS cubes:
#     lamsol.dat: contains a list of the wavelengths and the polynomial coefficients that
#                 describe the X,Y positions of all lenslets on the detector as a function
#                 of lenslet position on the lenslet array.
#     polychromekeyRXX.fits:  where XX is replaced by the spectral resolution defined in the
#                             parameters file. This is a multi-extension fits file with:
#                             - a list of the central wavelengths at which the final cube will be reduced to
#                             - an array of the X positions of all lenslets
#                             - an array of the Y positions of all lenslets
#                             - an array of booleans indicating whether that lenslet is good or not
#                             (e.g. when it is outside of the detector area)
#     polychromeRXX.fits: 3D arrays of size Nspec x Npix x Npix with maps of the PSFLets put in their correct
#                         positions for each wavelength bins that we want in the output cube. Each PSFLet
#                         in each wavelength slice is used for least-squares fitting.
#     hiresPolychromeRXX.fits: same as polychromeRXX.fits but this time using the high-resolution PSFLets
#     PSFLoc.fits:    nsubarr x nsubarr array of 2D high-resolution PSFLets at each location
#                     in the detector.

# %%
# we can check that the file list has been loaded:
log.info('Wavecal files: %s' % par.filelist)
# Out:
# crispy - INFO - Wavecal files: ['..//ReferenceFiles/wavecalR50_770_tight/det_700.fits', '..//ReferenceFiles/wavecalR50_770_tight/det_705.fits', '..//ReferenceFiles/wavecalR50_770_tight/det_710.fits', '..//ReferenceFiles/wavecalR50_770_tight/det_715.fits', '..//ReferenceFiles/wavecalR50_770_tight/det_720.fits', '..//ReferenceFiles/wavecalR50_770_tight/det_725.fits', '..//ReferenceFiles/wavecalR50_770_tight/det_730.fits', '..//ReferenceFiles/wavecalR50_770_tight/det_735.fits', '..//ReferenceFiles/wavecalR50_770_tight/det_740.fits', '..//ReferenceFiles/wavecalR50_770_tight/det_745.fits', '..//ReferenceFiles/wavecalR50_770_tight/det_750.fits', '..//ReferenceFiles/wavecalR50_770_tight/det_755.fits', '..//ReferenceFiles/wavecalR50_770_tight/det_760.fits', '..//ReferenceFiles/wavecalR50_770_tight/det_765.fits', '..//ReferenceFiles/wavecalR50_770_tight/det_770.fits', '..//ReferenceFiles/wavecalR50_770_tight/det_775.fits', '..//ReferenceFiles/wavecalR50_770_tight/det_780.fits', '..//ReferenceFiles/wavecalR50_770_tight/det_785.fits', '..//ReferenceFiles/wavecalR50_770_tight/det_790.fits', '..//ReferenceFiles/wavecalR50_770_tight/det_795.fits', '..//ReferenceFiles/wavecalR50_770_tight/det_800.fits', '..//ReferenceFiles/wavecalR50_770_tight/det_805.fits', '..//ReferenceFiles/wavecalR50_770_tight/det_810.fits', '..//ReferenceFiles/wavecalR50_770_tight/det_815.fits', '..//ReferenceFiles/wavecalR50_770_tight/det_820.fits', '..//ReferenceFiles/wavecalR50_770_tight/det_825.fits', '..//ReferenceFiles/wavecalR50_770_tight/det_830.fits', '..//ReferenceFiles/wavecalR50_770_tight/det_835.fits', '..//ReferenceFiles/wavecalR50_770_tight/det_840.fits']

# %% [markdown]
# One important aspect is that we can choose to use the same models for PSFLets as the one that was used to construct the monochromatic flatfields. This basically assumes that we have 100% knowledge of all the PSFLets, and can be set if par.gaussian_hires=True. Otherwise, we can actually use the deconvolution functions within crispy to approximate the lenslet PSFLets, by dividing up the detector into nsubarr^2 regions and averaging the PSFLets over these regions. Let's assume for now that we have excellent models of our PSFLets.

# %%
par.gaussian_hires=True # assuming we know the PSFLets perfectly a priori?

# %% [markdown]
# If you choose to change that to False, you should also change the following nsubarr parameter to >4 since there is likely variation of the PSFLet across the field of view. Let's go! This takes a few minutes. It will finish by a parallel process so don't worry if your computer heats up a bit.

# %%
buildcalibrations(par,
                    inspect=False,         # if True, constructs a bunch of images to verify a good calibration
                    inspect_first=True,         # if True, constructs an image to verify a good calibration
                    genwavelengthsol=True, # Compute wavelength at the center of all pixels
                    makehiresPSFlets=True, # this requires very high SNR on the monochromatic frames
                    makePSFWidths=True,
                    makePolychrome=True,   # This is needed to use least squares extraction
                    upsample=3,            # upsampling factor of the high-resolution PSFLets
                    nsubarr=3,             # the detector is divided into nsubarr^2 regions for PSFLet averaging
                    apodize=False,          # to match PSFlet spot locations, only use the inner circular part of the 
                                           #detector, hence discarding the corners of the detector where lenslets are 
                                           #distorted
                    finecal=False
                  )
# Out:
# crispy - INFO - Building calibration files, placing results in ..//ReferenceFiles/wavecalR50_770_tight/
# crispy - INFO - Read data from HDU 1 of ..//ReferenceFiles/wavecalR50_770_tight/det_700.fits
# crispy - INFO - Read data from HDU 1 of ..//ReferenceFiles/wavecalR50_770_tight/det_700.fits
# crispy - INFO - Mean, median, std: (10.003546637849626, 10.0, 3.1256748764882523)
# crispy - INFO - Initializing PSFlet location transformation coefficients
# crispy - INFO - Performing initial optimization of PSFlet location transformation coefficients for frame ..//ReferenceFiles/wavecalR50_770_tight/det_700.fits
# crispy - INFO - Array origin: (514.9930718028569, 518.4699884288003)
# crispy - INFO - Performing final optimization of PSFlet location transformation coefficients for frame ..//ReferenceFiles/wavecalR50_770_tight/det_700.fits
# crispy - INFO - Array origin: (515.0305574937572, 518.4854339982554)
# crispy - INFO - Read data from HDU 1 of ..//ReferenceFiles/wavecalR50_770_tight/det_705.fits
# crispy - INFO - Mean, median, std: (10.001584426460994, 10.0, 3.122659287307368)
# crispy - INFO - Initializing transformation coefficients with previous values
# crispy - INFO - Performing final optimization of PSFlet location transformation coefficients for frame ..//ReferenceFiles/wavecalR50_770_tight/det_705.fits
# crispy - INFO - Array origin: (515.7152935087007, 518.4857721730074)
# crispy - INFO - Read data from HDU 1 of ..//ReferenceFiles/wavecalR50_770_tight/det_710.fits
# crispy - INFO - Mean, median, std: (10.002211861227632, 10.0, 3.1231992055385356)
# crispy - INFO - Initializing transformation coefficients with previous values
# crispy - INFO - Performing final optimization of PSFlet location transformation coefficients for frame ..//ReferenceFiles/wavecalR50_770_tight/det_710.fits
# crispy - INFO - Array origin: (516.4772952665015, 518.4870337095152)
# crispy - INFO - Read data from HDU 1 of ..//ReferenceFiles/wavecalR50_770_tight/det_715.fits
# crispy - INFO - Mean, median, std: (10.006860116163205, 10.0, 3.1251237211750924)
# crispy - INFO - Initializing transformation coefficients with previous values
# crispy - INFO - Performing final optimization of PSFlet location transformation coefficients for frame ..//ReferenceFiles/wavecalR50_770_tight/det_715.fits
# crispy - INFO - Array origin: (517.1702041084352, 518.487340287268)
# crispy - INFO - Read data from HDU 1 of ..//ReferenceFiles/wavecalR50_770_tight/det_720.fits
# crispy - INFO - Mean, median, std: (10.00730471718333, 10.0, 3.1279552173236573)
# crispy - INFO - Initializing transformation coefficients with previous values
# crispy - INFO - Performing final optimization of PSFlet location transformation coefficients for frame ..//ReferenceFiles/wavecalR50_770_tight/det_720.fits
# crispy - INFO - Array origin: (517.8212873048144, 518.4880713808695)
# crispy - INFO - Read data from HDU 1 of ..//ReferenceFiles/wavecalR50_770_tight/det_725.fits
# crispy - INFO - Mean, median, std: (10.004044238057363, 10.0, 3.1265705079725064)
# crispy - INFO - Initializing transformation coefficients with previous values
# crispy - INFO - Performing final optimization of PSFlet location transformation coefficients for frame ..//ReferenceFiles/wavecalR50_770_tight/det_725.fits
# crispy - INFO - Array origin: (518.5428196116549, 518.4852092787706)
# crispy - INFO - Read data from HDU 1 of ..//ReferenceFiles/wavecalR50_770_tight/det_730.fits
# crispy - INFO - Mean, median, std: (10.004781149834375, 10.0, 3.12415783938793)
# crispy - INFO - Initializing transformation coefficients with previous values
# crispy - INFO - Performing final optimization of PSFlet location transformation coefficients for frame ..//ReferenceFiles/wavecalR50_770_tight/det_730.fits
# crispy - INFO - Array origin: (519.2400548691418, 518.4859365498928)
# crispy - INFO - Read data from HDU 1 of ..//ReferenceFiles/wavecalR50_770_tight/det_735.fits
# crispy - INFO - Mean, median, std: (10.01153597596696, 10.0, 3.1296233231475887)
# crispy - INFO - Initializing transformation coefficients with previous values
# crispy - INFO - Performing final optimization of PSFlet location transformation coefficients for frame ..//ReferenceFiles/wavecalR50_770_tight/det_735.fits
# crispy - INFO - Array origin: (519.9155342409318, 518.4867427511316)
# crispy - INFO - Read data from HDU 1 of ..//ReferenceFiles/wavecalR50_770_tight/det_740.fits
# crispy - INFO - Mean, median, std: (10.008831694638088, 10.0, 3.1227505009898766)
# crispy - INFO - Initializing transformation coefficients with previous values
# crispy - INFO - Performing final optimization of PSFlet location transformation coefficients for frame ..//ReferenceFiles/wavecalR50_770_tight/det_740.fits
# crispy - INFO - Array origin: (520.5960188815317, 518.4878804887853)
# crispy - INFO - Read data from HDU 1 of ..//ReferenceFiles/wavecalR50_770_tight/det_745.fits
# crispy - INFO - Mean, median, std: (10.010576675534198, 10.0, 3.1277979346084486)
# crispy - INFO - Initializing transformation coefficients with previous values
# crispy - INFO - Performing final optimization of PSFlet location transformation coefficients for frame ..//ReferenceFiles/wavecalR50_770_tight/det_745.fits
# crispy - INFO - Array origin: (521.2868578482766, 518.4866813061521)
# crispy - INFO - Read data from HDU 1 of ..//ReferenceFiles/wavecalR50_770_tight/det_750.fits
# crispy - INFO - Mean, median, std: (10.009319695388905, 10.0, 3.129233900262214)
# crispy - INFO - Initializing transformation coefficients with previous values
# crispy - INFO - Performing final optimization of PSFlet location transformation coefficients for frame ..//ReferenceFiles/wavecalR50_770_tight/det_750.fits
# crispy - INFO - Array origin: (521.9342633628005, 518.4863001518961)
# crispy - INFO - Read data from HDU 1 of ..//ReferenceFiles/wavecalR50_770_tight/det_755.fits
# crispy - INFO - Mean, median, std: (10.010950781480936, 10.0, 3.1289578522227393)
# crispy - INFO - Initializing transformation coefficients with previous values
# crispy - INFO - Performing final optimization of PSFlet location transformation coefficients for frame ..//ReferenceFiles/wavecalR50_770_tight/det_755.fits
# crispy - INFO - Array origin: (522.596873981104, 518.4879153844149)
# crispy - INFO - Read data from HDU 1 of ..//ReferenceFiles/wavecalR50_770_tight/det_760.fits
# crispy - INFO - Mean, median, std: (10.015158329325388, 10.0, 3.13151277560668)
# crispy - INFO - Initializing transformation coefficients with previous values
# crispy - INFO - Performing final optimization of PSFlet location transformation coefficients for frame ..//ReferenceFiles/wavecalR50_770_tight/det_760.fits
# crispy - INFO - Array origin: (523.2774963744351, 518.4858186544691)
# crispy - INFO - Read data from HDU 1 of ..//ReferenceFiles/wavecalR50_770_tight/det_765.fits
# crispy - INFO - Mean, median, std: (10.016077283338097, 10.0, 3.130861951817974)
# crispy - INFO - Initializing transformation coefficients with previous values
# crispy - INFO - Performing final optimization of PSFlet location transformation coefficients for frame ..//ReferenceFiles/wavecalR50_770_tight/det_765.fits
# crispy - INFO - Array origin: (523.9114420615838, 518.4860111639827)
# crispy - INFO - Read data from HDU 1 of ..//ReferenceFiles/wavecalR50_770_tight/det_770.fits
# crispy - INFO - Mean, median, std: (10.00577070430509, 10.0, 3.1257060788149245)
# crispy - INFO - Initializing transformation coefficients with previous values
# crispy - INFO - Performing final optimization of PSFlet location transformation coefficients for frame ..//ReferenceFiles/wavecalR50_770_tight/det_770.fits
# crispy - INFO - Array origin: (524.5583675464025, 518.4866358238185)
# crispy - INFO - Read data from HDU 1 of ..//ReferenceFiles/wavecalR50_770_tight/det_775.fits
# crispy - INFO - Mean, median, std: (10.01014098803871, 10.0, 3.1279202884401665)
# crispy - INFO - Initializing transformation coefficients with previous values
# crispy - INFO - Performing final optimization of PSFlet location transformation coefficients for frame ..//ReferenceFiles/wavecalR50_770_tight/det_775.fits
# crispy - INFO - Array origin: (525.231515934577, 518.4870698969283)
# crispy - INFO - Read data from HDU 1 of ..//ReferenceFiles/wavecalR50_770_tight/det_780.fits
# crispy - INFO - Mean, median, std: (10.012626447502385, 10.0, 3.130981423483406)
# crispy - INFO - Initializing transformation coefficients with previous values
# crispy - INFO - Performing final optimization of PSFlet location transformation coefficients for frame ..//ReferenceFiles/wavecalR50_770_tight/det_780.fits
# crispy - INFO - Array origin: (525.8465731632022, 518.4862640617669)
# crispy - INFO - Read data from HDU 1 of ..//ReferenceFiles/wavecalR50_770_tight/det_785.fits
# crispy - INFO - Mean, median, std: (10.010257351720528, 10.0, 3.1241297676101216)
# crispy - INFO - Initializing transformation coefficients with previous values
# crispy - INFO - Performing final optimization of PSFlet location transformation coefficients for frame ..//ReferenceFiles/wavecalR50_770_tight/det_785.fits
# crispy - INFO - Array origin: (526.4747263712072, 518.4876693368878)
# crispy - INFO - Read data from HDU 1 of ..//ReferenceFiles/wavecalR50_770_tight/det_790.fits
# crispy - INFO - Mean, median, std: (10.018990827300547, 10.0, 3.1347011182476865)
# crispy - INFO - Initializing transformation coefficients with previous values
# crispy - INFO - Performing final optimization of PSFlet location transformation coefficients for frame ..//ReferenceFiles/wavecalR50_770_tight/det_790.fits
# crispy - INFO - Array origin: (527.1552696214264, 518.487446274008)
# crispy - INFO - Read data from HDU 1 of ..//ReferenceFiles/wavecalR50_770_tight/det_795.fits
# crispy - INFO - Mean, median, std: (10.015902842548869, 10.0, 3.1320635774287022)
# crispy - INFO - Initializing transformation coefficients with previous values
# crispy - INFO - Performing final optimization of PSFlet location transformation coefficients for frame ..//ReferenceFiles/wavecalR50_770_tight/det_795.fits
# crispy - INFO - Array origin: (527.7404163503192, 518.486775569783)
# crispy - INFO - Read data from HDU 1 of ..//ReferenceFiles/wavecalR50_770_tight/det_800.fits
# crispy - INFO - Mean, median, std: (10.013166057832564, 10.0, 3.128515380001911)
# crispy - INFO - Initializing transformation coefficients with previous values
# crispy - INFO - Performing final optimization of PSFlet location transformation coefficients for frame ..//ReferenceFiles/wavecalR50_770_tight/det_800.fits
# crispy - INFO - Array origin: (528.4003435010835, 518.487254772798)
# crispy - INFO - Read data from HDU 1 of ..//ReferenceFiles/wavecalR50_770_tight/det_805.fits
# crispy - INFO - Mean, median, std: (10.01786977231255, 10.0, 3.131550789745421)
# crispy - INFO - Initializing transformation coefficients with previous values
# crispy - INFO - Performing final optimization of PSFlet location transformation coefficients for frame ..//ReferenceFiles/wavecalR50_770_tight/det_805.fits
# crispy - INFO - Array origin: (529.0233449704886, 518.4876317322011)
# crispy - INFO - Read data from HDU 1 of ..//ReferenceFiles/wavecalR50_770_tight/det_810.fits
# crispy - INFO - Mean, median, std: (10.01796958362159, 10.0, 3.1316755580337516)
# crispy - INFO - Initializing transformation coefficients with previous values
# crispy - INFO - Performing final optimization of PSFlet location transformation coefficients for frame ..//ReferenceFiles/wavecalR50_770_tight/det_810.fits
# crispy - INFO - Array origin: (529.6176272862941, 518.4866348893877)
# crispy - INFO - Read data from HDU 1 of ..//ReferenceFiles/wavecalR50_770_tight/det_815.fits
# crispy - INFO - Mean, median, std: (10.017042750062798, 10.0, 3.1319907035738197)
# crispy - INFO - Initializing transformation coefficients with previous values
# crispy - INFO - Performing final optimization of PSFlet location transformation coefficients for frame ..//ReferenceFiles/wavecalR50_770_tight/det_815.fits
# crispy - INFO - Array origin: (530.2556997088271, 518.4861905795354)
# crispy - INFO - Read data from HDU 1 of ..//ReferenceFiles/wavecalR50_770_tight/det_820.fits
# crispy - INFO - Mean, median, std: (10.020554685293638, 10.0, 3.1343160752847705)
# crispy - INFO - Initializing transformation coefficients with previous values
# crispy - INFO - Performing final optimization of PSFlet location transformation coefficients for frame ..//ReferenceFiles/wavecalR50_770_tight/det_820.fits
# crispy - INFO - Array origin: (530.8445491941415, 518.4864378657719)
# crispy - INFO - Read data from HDU 1 of ..//ReferenceFiles/wavecalR50_770_tight/det_825.fits
# crispy - INFO - Mean, median, std: (10.016867757291227, 10.0, 3.131229590710042)
# crispy - INFO - Initializing transformation coefficients with previous values
# crispy - INFO - Performing final optimization of PSFlet location transformation coefficients for frame ..//ReferenceFiles/wavecalR50_770_tight/det_825.fits
# crispy - INFO - Array origin: (531.4416850327395, 518.4863414787316)
# crispy - INFO - Read data from HDU 1 of ..//ReferenceFiles/wavecalR50_770_tight/det_830.fits
# crispy - INFO - Mean, median, std: (10.023004002651488, 10.0, 3.13531979623052)
# crispy - INFO - Initializing transformation coefficients with previous values
# crispy - INFO - Performing final optimization of PSFlet location transformation coefficients for frame ..//ReferenceFiles/wavecalR50_770_tight/det_830.fits
# crispy - INFO - Array origin: (532.0490841827708, 518.4867988530702)
# crispy - INFO - Read data from HDU 1 of ..//ReferenceFiles/wavecalR50_770_tight/det_835.fits
# crispy - INFO - Mean, median, std: (10.01861474528812, 10.0, 3.1349387469786185)
# crispy - INFO - Initializing transformation coefficients with previous values
# crispy - INFO - Performing final optimization of PSFlet location transformation coefficients for frame ..//ReferenceFiles/wavecalR50_770_tight/det_835.fits
# crispy - INFO - Array origin: (532.6756513588467, 518.4848755000166)
# crispy - INFO - Read data from HDU 1 of ..//ReferenceFiles/wavecalR50_770_tight/det_840.fits
# crispy - INFO - Mean, median, std: (10.020076935340473, 10.0, 3.1340324712025374)
# crispy - INFO - Initializing transformation coefficients with previous values
# crispy - INFO - Performing final optimization of PSFlet location transformation coefficients for frame ..//ReferenceFiles/wavecalR50_770_tight/det_840.fits
# crispy - INFO - Array origin: (533.2512662851366, 518.4872410709886)
# crispy - INFO - Saving wavelength solution to ..//ReferenceFiles/wavecalR50_770_tight/lamsol.dat
# crispy - INFO - Computing wavelength values at pixel centers
# crispy - INFO - Making high-resolution PSFLet models
# crispy - INFO - Starting parallel computation
# crispy - INFO - Computing PSFLet widths...
# crispy - INFO - Reduced cube will have 18 wavelength bins
# crispy - INFO - Making polychrome cube
# crispy - INFO - Saving polychrome cube
# crispy - INFO - Saving wavelength calibration cube
# crispy - INFO - Total time elapsed: 413 s

# %% [markdown]
# Let's take a look at the files we constructed:

# %%
os.listdir(par.wavecalDir)
# Out:
# ['hires_psflets_lam745.fits',
#  'hires_psflets_lam790.fits',
#  'hires_psflets_lam840.fits',
#  'det_770.fits',
#  'det_750.fits',
#  'polychromeR50stack.fits.gz',
#  'calib.fits',
#  'det_785.fits',
#  'hires_psflets_lam765.fits',
#  'det_815.fits',
#  'hires_psflets_lam725.fits',
#  '.DS_Store',
#  'det_710.fits',
#  'hires_psflets_lam820.fits',
#  'hires_psflets_lam800.fits',
#  'det_730.fits',
#  'hires_psflets_lam705.fits',
#  'PSFloc.fits',
#  'inspection_700.png',
#  'det_835.fits',
#  'det_740.fits',
#  'hires_psflets_lam775.fits',
#  'det_795.fits',
#  'hires_psflets_lam755.fits',
#  'det_760.fits',
#  'hires_psflets_lam780.fits',
#  'det_720.fits',
#  'hires_psflets_lam810.fits',
#  'det_825.fits',
#  'hires_psflets_lam715.fits',
#  'hires_psflets_lam735.fits',
#  'det_805.fits',
#  'hires_psflets_lam830.fits',
#  'det_700.fits',
#  'det_810.fits',
#  'hires_psflets_lam720.fits',
#  'det_715.fits',
#  'polychromeR50.fits.gz',
#  'hires_psflets_lam825.fits',
#  'hires_psflets_lam805.fits',
#  'PSFwidths.fits',
#  'det_735.fits',
#  'hires_psflets_lam700.fits',
#  'det_830.fits',
#  'hires_psflets_lam740.fits',
#  'hires_psflets_lam795.fits',
#  'det_775.fits',
#  'det_755.fits',
#  'det_780.fits',
#  'polychromekeyR50.fits',
#  'hires_psflets_lam760.fits',
#  'det_725.fits',
#  'hires_psflets_lam815.fits',
#  'det_820.fits',
#  'hires_psflets_lam710.fits',
#  'hires_psflets_lam730.fits',
#  'det_800.fits',
#  'lamsol.dat',
#  'hires_psflets_lam835.fits',
#  'det_705.fits',
#  'det_745.fits',
#  'hires_psflets_lam770.fits',
#  'det_840.fits',
#  'det_790.fits',
#  'hires_psflets_lam750.fits',
#  'det_765.fits',
#  'hires_psflets_lam785.fits']

# %% [markdown]
# Some of these files are described and explained in the papers associated with this work.

# %% [markdown]
# ## Construct fields to extract

# %% [markdown]
# Now, let's construct a field that we will want to extract. For example, we will use a flatfield.

# %%
from crispy.unitTests import testCreateFlatfield
help(testCreateFlatfield)
# Out:
# Help on function testCreateFlatfield in module crispy.unitTests:
#
# testCreateFlatfield(par, pixsize=0.1, npix=512, pixval=1.0, Nspec=45, outname='flatfield.fits', useQE=True, method='optext', maxflux=400, bg=10)
#     Creates a polychromatic flatfield
#
#     Parameters
#     ----------
#     par :   Parameter instance
#         Contains all IFS parameters
#     pixsize:   float
#        Pixel scale (lam/D)
#     npix: int
#         Each input frame has a pixel size npix x npix
#     pixval: float
#         Each input frame has a unform value pixval in photons per second per nm of bandwidth
#     Nspec: float
#         Optional input forcing the number of wavelengths bins used
#     outname: string
#         Name of flatfield image
#     useQE: boolean
#         Whether to take into account the wavelength-dependent QE of the detector

# %%
par.savePoly=True
par.saveRotatedInput = True
testCreateFlatfield(par,npix=600,maxflux=50, bg=50, useQE=False)
# Out:
# crispy - INFO - Reduced cube will have 44 wavelength bins
# crispy - INFO - The number of input pixels per lenslet is 5.016181
# crispy - INFO - Using PSFlet gaussian approximation
# crispy - WARNING - Assuming endpoints wavelist is given
# crispy - INFO - Creating Gaussian PSFLet templates
# crispy - INFO - Writing data to ..//SimResults/imagePlaneRot.fits
# crispy - INFO - Writing data to ..//SimResults/detectorFramepoly.fits
# crispy - INFO - Done.
# crispy - INFO - Performance: 55 seconds total
# crispy - INFO - Writing data to ..//unitTestsOutputs/flatfield.fits

# %%
from crispy.tools.image import Image
plt.figure(figsize=(10,10))
plt.imshow(Image(par.unitTestsOutputs+'/flatfield.fits').data)
plt.show()
plt.figure(figsize=(10,10))
plt.imshow(Image(par.unitTestsOutputs+'/flatfield.fits').data[500:550,500:550])
plt.axis('off')
plt.show()
# Out:
# crispy - INFO - Read data from HDU 1 of ..//unitTestsOutputs/flatfield.fits
# crispy - INFO - Read data from HDU 1 of ..//unitTestsOutputs/flatfield.fits

# %% [markdown]
# ## Reduce the flatfield!

# %%
from crispy.tools.image import Image
from crispy.IFS import reduceIFSMap
help(reduceIFSMap)
detector = reduceIFSMap(par,par.unitTestsOutputs+'/flatfield.fits',
                        method='lstsq_conv',
                        smoothbad=False,
                        pixnoise=50,
                        fitbkgnd=True,
                        medsub=False,
                        gain=1.0,
                        niter=3
                       )
# Out:
# Help on function reduceIFSMap in module crispy.IFS:
#
# reduceIFSMap(par, IFSimageName, method='optext', smoothbad=True, name=None, hires=False, dy=3, fitbkgnd=True, specialPolychrome=None, returnall=False, niter=10, pixnoise=None, medsub=True, normpsflets=False, gain=0.5)
#     Main reduction function
#
#     Uses various routines to extract an IFS detector map into a spectral-spatial cube.
#
#     Parameters
#     ----------
#     par :   Parameter instance
#             Contains all IFS parameters
#     IFSimageName : string or 2D ndarray
#             Path of image file, of 2D ndarray.
#     method : 'lstsq', 'optext'
#             Method used for reduction.
#             'lstsq': use the knowledge of the PSFs at each location and each wavelength and fits
#             the microspectrum as a weighted sum of these PSFs in the least-square sense. Can weigh the data by its variance.
#             'optext': use a matched filter to appropriately weigh each pixel and assign the fluxes, making use of the inverse
#             wavlength calibration map. Then remap each microspectrum onto the desired wavelengths
#
#     Returns
#     -------
#     cube: 3D ndarray
#         Reduced IFS cube
#
# crispy - INFO - Read data from HDU 1 of ..//unitTestsOutputs/flatfield.fits
# crispy - INFO - Mean, median, std: (1.6877991790337858, 1.0, 8.34969691376993)
# crispy - INFO - Reduced cube will have 18 wavelength bins
# crispy - INFO - Adding an extra flat component to fit, N=19
# crispy - INFO - Writing data to ..//SimResults/flatfield_red_lstsq_conv_resid.fits
# crispy - INFO - Writing data to ..//SimResults/flatfield_red_lstsq_conv_model.fits
# crispy - INFO - Writing data to ..//SimResults/flatfield_red_lstsq_conv_chisq.fits
# crispy - INFO - Writing data to ..//SimResults/flatfield_red_lstsq_conv_offsets.fits
# crispy - INFO - Elapsed time: 26.467130s

# %% [markdown]
# Let's plot what we have got

# %%
from crispy.tools.image import Image
ftsize = 15
cmap='viridis'
plt.figure(figsize=(10,10))
# plt.imshow(Image(par.exportDir+'/flatfield_red_lstsq_conv.fits').data[5],cmap=cmap)
plt.imshow(Image(par.exportDir+'/flatfield_red_lstsq.fits').data[5],cmap=cmap)
plt.axis('off')
plt.colorbar(fraction=0.046, pad=0.04)
plt.title('Data',fontsize=ftsize)
plt.show()
# Out:
# crispy - INFO - Read data from HDU 1 of ..//SimResults/flatfield_red_lstsq.fits
# crispy - INFO - Read inverse variance from HDU 2 of ..//SimResults/flatfield_red_lstsq.fits

# %%
from astropy.io import fits
cmap='inferno'
ftsize = 20
BB = fits.getdata(par.unitTestsOutputs+"/flatfield.fits")
BBres = fits.getdata(par.exportDir+'/flatfield_red_lstsq_conv_resid.fits')
BBmod = fits.getdata(par.exportDir+'/flatfield_red_lstsq_conv_model.fits')
# BBres = fits.getdata(par.exportDir+'/flatfield_red_lstsq_resid.fits')
# BBmod = fits.getdata(par.exportDir+'/flatfield_red_lstsq_model.fits')
plt.figure(figsize=(12,10))
plt.subplot(131)
plt.imshow(BB[850:-100,150:300].T,vmin=0,vmax=np.amax(BB[850:-100,150:300]),cmap=cmap)
plt.axis('off')
plt.colorbar(fraction=0.046, pad=0.04,orientation='horizontal')
plt.title('Data',fontsize=ftsize)
plt.subplot(132)
plt.imshow(BBmod[850:-100,150:300].T,vmin=0,vmax=np.amax(BB[850:-100,150:300]),cmap=cmap)
plt.axis('off')
plt.colorbar(fraction=0.046, pad=0.04,orientation='horizontal')
plt.title('Model',fontsize=ftsize)
plt.subplot(133)
plt.imshow(100*BBres[850:-100,150:300].T/np.amax(BB[850:-120,150:300].T),cmap=cmap)
# plt.imshow(BBres[850:-100,150:300].T,cmap=cmap)
plt.axis('off')
plt.colorbar(fraction=0.046, pad=0.04,orientation='horizontal')
plt.title('Residuals (\% of data max)',fontsize=ftsize)
plt.tight_layout()
plt.savefig('/Users/mrizzo/Downloads/DataModelResiduals.pdf',
            dpi=150, bbox_inches='tight')
plt.show()

# %%
from astropy.io import fits
cmap='inferno'
ftsize = 20
BB = fits.getdata(par.unitTestsOutputs+"/flatfield.fits")
BBres = fits.getdata(par.exportDir+'/flatfield_red_lstsq_conv_resid.fits')
BBmod = fits.getdata(par.exportDir+'/flatfield_red_lstsq_conv_model.fits')
# BBres = fits.getdata(par.exportDir+'/flatfield_red_lstsq_resid.fits')
# BBmod = fits.getdata(par.exportDir+'/flatfield_red_lstsq_model.fits')
# plt.figure(figsize=(12,7))
fig, axarr = plt.subplots(3, 1, figsize=(10, 10))
im = axarr[0].imshow(BB[850:-100,150:300],vmin=-10.,vmax=np.amax(BB[850:-100,150:300]),cmap=cmap)
axarr[0].axis('off')
# axarr[0].colorbar(fraction=0.046, pad=0.04,orientation='vertical')
axarr[0].set_title('Data',fontsize=ftsize)
# plt.subplot(312)
axarr[1].imshow(BBmod[850:-100,150:300],vmin=-10.,vmax=np.amax(BB[850:-100,150:300]),cmap=cmap)
axarr[1].axis('off')
# plt.colorbar(fraction=0.046, pad=0.04,orientation='vertical')
axarr[1].set_title('Model',fontsize=ftsize)
# plt.subplot(313)
im2 = axarr[2].imshow(100*BBres[850:-100,150:300]/np.amax(BB[850:-120,150:300]),cmap=cmap)
# plt.imshow(BBres[850:-100,150:300].T,cmap=cmap)
axarr[2].axis('off')
# plt.colorbar(fraction=0.046, pad=0.04,orientation='vertical')
axarr[2].set_title('Residuals (\% of data max)',fontsize=ftsize)
# plt.tight_layout()

# fig.subplots_adjust(right=0.6, wspace=0.1, hspace=0.25)
cbar_ax = fig.add_axes([0.75, 0.42, 0.05, 0.44])
fig.colorbar(im, cax=cbar_ax)
cbar_ax = fig.add_axes([0.75, 0.16, 0.05, 0.15])
fig.colorbar(im2, cax=cbar_ax)

plt.savefig('/Users/mrizzo/Downloads/DataModelResiduals.pdf',
            dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Extraction metric

# %%
plt.figure(figsize=(7,5))
# plt.title(r'$\chi^2$ map for all microspectra')
plt.imshow(Image(par.exportDir+'/flatfield_red_lstsq_chisq.fits').data,cmap=cmap)
plt.colorbar(fraction=0.046, pad=0.04)
plt.axis('off')
plt.savefig('/Users/mrizzo/Downloads/Chi2Map.pdf',
            dpi=150, bbox_inches='tight')
img = Image(par.exportDir+'/flatfield_red_lstsq_chisq.fits').data
print(np.nanmean(img), np.nanstd(img))
# Out:
# crispy - INFO - Read data from HDU 1 of ..//SimResults/flatfield_red_lstsq_chisq.fits
# crispy - INFO - Read data from HDU 1 of ..//SimResults/flatfield_red_lstsq_chisq.fits
# (0.9530712, 0.11683355)

# %% [markdown]
# If we want to know the correspondence between slice and wavelength, we can do the following

# %%
from crispy.tools.reduction import calculateWaveList
lam_midpts,lam_endpts = calculateWaveList(par,method='lstsq')
print('Wavelengths at midpoints for lstsq (nm): ',lam_midpts)
print('Wavelengths at endpoints for lstsq (nm): ',lam_endpts)
lam_midpts,lam_endpts = calculateWaveList(par,method='optext')
print('Wavelengths at midpoints for optext (nm): ',lam_midpts)
print('Wavelengths at endpoints for optext (nm): ',lam_endpts)
# Out:
# crispy - INFO - Reduced cube will have 18 wavelength bins
# ('Wavelengths at midpoints for lstsq (nm): ', array([704.25443039, 711.41747416, 718.65337398, 725.96287087,
#        733.34671341, 740.80565776, 748.34046779, 755.95191515,
#        763.64077932, 771.40784771, 779.25391575, 787.17978694,
#        795.18627299, 803.27419382, 811.44437771, 819.69766139,
#        828.03489005, 836.45691752]))
# ('Wavelengths at endpoints for lstsq (nm): ', array([700.7       , 707.82689129, 715.02627093, 722.29887618,
#        729.64545185, 737.0667503 , 744.56353152, 752.13656328,
#        759.78662111, 767.51448846, 775.32095674, 783.20682541,
#        791.17290206, 799.22000248, 807.34895079, 815.56057945,
#        823.85572944, 832.23525024, 840.7       ]))
# crispy - INFO - Reduced cube will have 18 wavelength bins
# ('Wavelengths at midpoints for optext (nm): ', array([704.25443039, 711.41747416, 718.65337398, 725.96287087,
#        733.34671341, 740.80565776, 748.34046779, 755.95191515,
#        763.64077932, 771.40784771, 779.25391575, 787.17978694,
#        795.18627299, 803.27419382, 811.44437771, 819.69766139,
#        828.03489005, 836.45691752]))
# ('Wavelengths at endpoints for optext (nm): ', array([700.7       , 707.82689129, 715.02627093, 722.29887618,
#        729.64545185, 737.0667503 , 744.56353152, 752.13656328,
#        759.78662111, 767.51448846, 775.32095674, 783.20682541,
#        791.17290206, 799.22000248, 807.34895079, 815.56057945,
#        823.85572944, 832.23525024, 840.7       ]))

# %% [markdown]
# ## Start from known wavecal

# %% [markdown]
# In the case where we want to use another wavecal (e.g. obtained from lab measurements), we can set this up with par.PSFLetPositions = True

# %%
# par.PSFLetPositions = True
# par.wavecalDir = par.prefix+'/Calibra_170425/'

# watch out to be sure you have the correct R that matches the wavecal! In this case, it is R=70
#par.R = 70

# %% [markdown]
# Repeat the flatfield exercise

# %%
#from crispy.unitTests import testCreateFlatfield
#testCreateFlatfield(par,useQE=False)

# %%
# par.PSFLetPositions = False
# par.R=50
# par.wavecalDir = par.prefix+'/wavecalR50_SC/'

# %%
# from crispy.unitTests import testCrosstalk
# testCrosstalk(par,pixval=25,method='optext',useQE=False)
# extracted = reduceIFSMap(par,par.unitTestsOutputs+'/crosstalk.fits',method='lstsq',smoothbad=False)

# %%
# extracted = reduceIFSMap(par,par.unitTestsOutputs+'/flatfield.fits',method='lstsq',smoothbad=False)

# %% [markdown]
# ## Scratch - Explore the extraction

# %%
from crispy.tools.reduction import get_cutout,fit_cutout
polychromeR = fits.open(
                par.wavecalDir +
                'polychromeR%d.fits.gz' %
                (par.R))
psflets = polychromeR[0].data
polychromekey = fits.open(
    par.wavecalDir +
    'polychromekeyR%d.fits' %
    (par.R))
xindx = polychromekey[1].data
yindx = polychromekey[2].data
good = polychromekey[3].data
ifsimage = Image(par.unitTestsOutputs+'/flatfield.fits')


cube = np.zeros((psflets.shape[0], par.nlens, par.nlens))
ivarcube = np.zeros((psflets.shape[0], par.nlens, par.nlens))

model = np.zeros(ifsimage.data.shape)
resid = ifsimage.data.copy()

i=54
j=54
normpsflets=False
dy=3
subim, psflet_subarr, [y0, y1, x0, x1] = get_cutout(
    ifsimage, xindx[:, i, j], yindx[:, i, j], psflets, dy, normpsflets=normpsflets)
# Out:
# crispy - INFO - Read data from HDU 1 of ..//unitTestsOutputs/flatfield.fits

# %%
plt.imshow(subim)
plt.colorbar(orientation='horizontal')

# %%
cube[:, j, i], ivarcube[:, j, i], modelij, chi2ij = fit_cutout(
    subim.copy(), psflet_subarr.copy(), mode='lstsq_conv',
    niter=3, pixnoise=10.0)

# %%
plt.imshow(modelij)
plt.colorbar(orientation='horizontal')
print chi2ij
# Out:
# 3.609192067268154

# %%
plt.imshow(subim-modelij)
print np.std(subim-modelij)
plt.colorbar(orientation='horizontal')
# Out:
# 6.809523122465349

# %%
from crispy.tools.reduction import lstsqExtract
from crispy.tools.image import Image
ifsimage = Image(par.unitTestsOutputs+'/flatfield.fits')
cube, model, resid = lstsqExtract(par, par.exportDir+'/test', ifsimage, smoothandmask=False, ivar=True, dy=3,
                 refine=False, hires=False, upsample=3, fitbkgnd=True,
                 specialPolychrome=None, returnall=True, mode='lstsq',
                 niter=3, pixnoise=10.0, normpsflets=False, gain=1.0)
# Out:
# crispy - INFO - Read data from HDU 1 of ..//unitTestsOutputs/flatfield.fits
# crispy - INFO - Reduced cube will have 18 wavelength bins
# crispy - INFO - Adding an extra flat component to fit, N=19
# crispy - INFO - Writing data to ..//SimResults/test_resid.fits
# crispy - INFO - Writing data to ..//SimResults/test_model.fits
# crispy - INFO - Writing data to ..//SimResults/test_chisq.fits
# crispy - INFO - Writing data to ..//SimResults/test_offsets.fits
